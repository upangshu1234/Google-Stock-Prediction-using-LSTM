# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv('/content/GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index
google_stock_data.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()

# %% [markdown]
# Data Pre-Processing

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %% [markdown]
# Creating LSTM model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50, 50)         │        10,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │           102 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,902 (120.71 KB)
#  Trainable params: 30,902 (120.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0312 - mean_absolute_error: 0.1329 - val_loss: 0.0232 - val_mean_absolute_error: 0.1327
# Epoch 2/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - mean_absolute_error: 0.0296 - val_loss: 0.0081 - val_mean_absolute_error: 0.0758
# Epoch 3/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.2974e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0036 - val_mean_absolute_error: 0.0481
# Epoch 4/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1711e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0031 - val_mean_absolute_error: 0.0446
# Epoch 5/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9461e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0032 - val_mean_absolute_error: 0.0448
# Epoch 6/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4404e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0030 - val_mean_absolute_error: 0.0438
# Epoch 7/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4567e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0052 - val_mean_absolute_error: 0.0603
# Epoch 8/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1713e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0032 - val_mean_absolute_error: 0.0453
# Epoch 9/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7755e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0030 - val_mean_absolute_error: 0.0442
# Epoch 10/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6617e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0027 - val_mean_absolute_error: 0.0409
# Epoch 11/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9730e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0038 - val_mean_absolute_error: 0.0509
# Epoch 12/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6889e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0055 - val_mean_absolute_error: 0.0626
# Epoch 13/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8543e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0060 - val_mean_absolute_error: 0.0658
# Epoch 14/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3131e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0037 - val_mean_absolute_error: 0.0486
# Epoch 15/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2225e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0073 - val_mean_absolute_error: 0.0727
# Epoch 16/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4873e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0069 - val_mean_absolute_error: 0.0710
# Epoch 17/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7403e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0029 - val_mean_absolute_error: 0.0419
# Epoch 18/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.2361e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0039 - val_mean_absolute_error: 0.0499
# Epoch 19/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8061e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0071 - val_mean_absolute_error: 0.0719
# Epoch 20/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.1103e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0020 - val_mean_absolute_error: 0.0347
# Epoch 21/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1355e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0032 - val_mean_absolute_error: 0.0452
# Epoch 22/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2292e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0045 - val_mean_absolute_error: 0.0559
# Epoch 23/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6450e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0054 - val_mean_absolute_error: 0.0627
# Epoch 24/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9183e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0055 - val_mean_absolute_error: 0.0629
# Epoch 25/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9818e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0027 - val_mean_absolute_error: 0.0402
# Epoch 26/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9498e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0031 - val_mean_absolute_error: 0.0447
# Epoch 27/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6302e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0020 - val_mean_absolute_error: 0.0349
# Epoch 28/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4240e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0043 - val_mean_absolute_error: 0.0548
# Epoch 29/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5012e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0026 - val_mean_absolute_error: 0.0411
# Epoch 30/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4999e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0034 - val_mean_absolute_error: 0.0477
# Epoch 31/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4781e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0026 - val_mean_absolute_error: 0.0404
# Epoch 32/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6561e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0025 - val_mean_absolute_error: 0.0397
# Epoch 33/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1574e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0101 - val_mean_absolute_error: 0.0898
# Epoch 34/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8509e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0048 - val_mean_absolute_error: 0.0591
# Epoch 35/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2930e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0052 - val_mean_absolute_error: 0.0614
# Epoch 36/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2095e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0027 - val_mean_absolute_error: 0.0414
# Epoch 37/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2004e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0038 - val_mean_absolute_error: 0.0509
# Epoch 38/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1196e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0038 - val_mean_absolute_error: 0.0516
# Epoch 39/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0974e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0041 - val_mean_absolute_error: 0.0527
# Epoch 40/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3556e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0053 - val_mean_absolute_error: 0.0625
# Epoch 41/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2947e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0032 - val_mean_absolute_error: 0.0457
# Epoch 42/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3709e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0026 - val_mean_absolute_error: 0.0411
# Epoch 43/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3669e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0039 - val_mean_absolute_error: 0.0519
# Epoch 44/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0402e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0024 - val_mean_absolute_error: 0.0391
# Epoch 45/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1141e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0019 - val_mean_absolute_error: 0.0336
# Epoch 46/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1498e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0039 - val_mean_absolute_error: 0.0514
# Epoch 47/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8546e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0054 - val_mean_absolute_error: 0.0622
# Epoch 48/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9280e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0048 - val_mean_absolute_error: 0.0585
# Epoch 49/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0107e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0058 - val_mean_absolute_error: 0.0670
# Epoch 50/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8599e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0044 - val_mean_absolute_error: 0.0544
# Epoch 51/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7076e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0045 - val_mean_absolute_error: 0.0555
# Epoch 52/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9792e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0058 - val_mean_absolute_error: 0.0656
# Epoch 53/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7973e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0031 - val_mean_absolute_error: 0.0452
# Epoch 54/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7734e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0029 - val_mean_absolute_error: 0.0437
# Epoch 55/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7087e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0040 - val_mean_absolute_error: 0.0522
# Epoch 56/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6704e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0048 - val_mean_absolute_error: 0.0582
# Epoch 57/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4980e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0042 - val_mean_absolute_error: 0.0540
# Epoch 58/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5679e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0030 - val_mean_absolute_error: 0.0439
# Epoch 59/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7728e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0042 - val_mean_absolute_error: 0.0546
# Epoch 60/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6883e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0055 - val_mean_absolute_error: 0.0633
# Epoch 61/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5469e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0040 - val_mean_absolute_error: 0.0522
# Epoch 62/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5253e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0055 - val_mean_absolute_error: 0.0633
# Epoch 63/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5073e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0026 - val_mean_absolute_error: 0.0410
# Epoch 64/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5614e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0038 - val_mean_absolute_error: 0.0501
# Epoch 65/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7192e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0050 - val_mean_absolute_error: 0.0599
# Epoch 66/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6476e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0040 - val_mean_absolute_error: 0.0525
# Epoch 67/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4907e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0027 - val_mean_absolute_error: 0.0419
# Epoch 68/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5159e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0049 - val_mean_absolute_error: 0.0600
# Epoch 69/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5254e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0051 - val_mean_absolute_error: 0.0609
# Epoch 70/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3333e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0043 - val_mean_absolute_error: 0.0546
# Epoch 71/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4621e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0028 - val_mean_absolute_error: 0.0415
# Epoch 72/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2600e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0053 - val_mean_absolute_error: 0.0612
# Epoch 73/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5208e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0043 - val_mean_absolute_error: 0.0544
# Epoch 74/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2828e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0030 - val_mean_absolute_error: 0.0435
# Epoch 75/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1963e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0036 - val_mean_absolute_error: 0.0486
# Epoch 76/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1144e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0037 - val_mean_absolute_error: 0.0490
# Epoch 77/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3496e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0044 - val_mean_absolute_error: 0.0536
# Epoch 78/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2752e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0037 - val_mean_absolute_error: 0.0495
# Epoch 79/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2254e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0044 - val_mean_absolute_error: 0.0552
# Epoch 80/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5058e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0033 - val_mean_absolute_error: 0.0452

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# array([[0.48812637, 0.489218  ],
#        [0.49441236, 0.49513522],
#        [0.50024503, 0.5005916 ],
#        [0.5154521 , 0.51615804],
#        [0.52554256, 0.5263233 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1575.9471, 1574.9473],
#        [1587.601 , 1585.914 ],
#        [1598.4143, 1596.0265],
#        [1626.6069, 1624.8763],
#        [1645.3138, 1643.7161]], dtype=float32)

# %% [markdown]
# Visualizing predicted and actual data

# %%
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1575.947144      1574.947266
# 2020-08-25  1582.07  1608.22     1587.600952      1585.913940
# 2020-08-26  1608.00  1652.38     1598.414307      1596.026489
# 2020-08-27  1653.68  1634.33     1626.606934      1624.876343
# 2020-08-28  1633.49  1644.41     1645.313843      1643.716064

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# Predicting upcoming 10 days

# %%
future_dates = pd.date_range(
    start=gs_slic_data.index[-1] + pd.Timedelta(days=1),
    periods=10,
    freq='D'
)

new_rows = pd.DataFrame(index=future_dates, columns=gs_slic_data.columns)

gs_slic_data = pd.concat([gs_slic_data, new_rows])

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2269.838623      2284.498779
# 2021-06-10  2494.01  2521.60     2278.155029      2292.209473
# 2021-06-11  2524.92  2513.93     2287.511475      2300.988281
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
